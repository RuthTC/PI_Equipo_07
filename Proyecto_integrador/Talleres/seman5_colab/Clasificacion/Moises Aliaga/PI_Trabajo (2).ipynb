# %%
# 1. Importaciones limpias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
#url = " "
#dfl = pd.read_csv(url)
#dfl.head()

# %%
df = pd.read_csv("/content/Ozone_daily_aqs_data_downloaded_2026-09-17 19_53_11.csv")
df.head() #vemos los 5 primeros datos en el data frame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2408/1342087751.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/Ozone_daily_aqs_data_downloaded_2026-09-17 19_53_11.csv")
#       2 df.head() #vemos los 5 primeros datos en el data frame
#
# ...

# %% [markdown]
# Consultar información básica sobre el conjunto de datos

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14557 entries, 0 to 14556
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           14557 non-null  object
#  1   Site ID                        14557 non-null  int64
#  2   POC                            14557 non-null  int64
#  3   Daily Max Ozone Concentration  14557 non-null  float64
#  4   Units                          14557 non-null  object
#  5   Daily AQI Value                14557 non-null  int64
#  6   Local Site Name                14557 non-null  object
#  7   Daily Obs Count                14557 non-null  int64
#  8   Percent Complete               14557 non-null  int64
#  9   AQS Parameter Code             14557 non-null  int64
#  10  AQS Parameter Description      14557 non-null  object
#  11  Method Code                    14557 non-null  int64
# ...

# %% [markdown]
# describe () >> resumen de estadísticas

# %%
df.describe().round(1)
# Out:
#           Site ID      POC  Daily Max Ozone Concentration  Daily AQI Value  \
# count     14557.0  14557.0                        14557.0          14557.0
# mean   10820045.1      1.0                            0.0             38.9
# std      287468.3      0.0                            0.0             12.2
# min    10030010.0      1.0                            0.0              0.0
# 25%    10730023.0      1.0                            0.0             31.0
# 50%    10890014.0      1.0                            0.0             38.0
# 75%    11030011.0      1.0                            0.0             44.0
# max    11250011.0      1.0                            0.1            140.0
#
#        Daily Obs Count  Percent Complete  AQS Parameter Code  Method Code  \
# count          14557.0           14557.0             14557.0      14557.0
# mean              16.8              98.7             44201.0         84.0
# ...

# %% [markdown]
# columns >> obtiene los nombres de las características

# %%
df.columns
# Out:
# Index(['Date', 'Site ID', 'POC', 'Daily Max Ozone Concentration', 'Units',
#        'Daily AQI Value', 'Local Site Name', 'Daily Obs Count',
#        'Percent Complete', 'AQS Parameter Code', 'AQS Parameter Description',
#        'Method Code', 'Method Description', 'CBSA Code', 'CBSA Name',
#        'Site Latitude', 'Site Longitude', 'Dominant Source', 'Elevation (m)',
#        'Measurement Scale', 'Measurement Scale Definition', 'Monitor Type',
#        'Monitoring Agency', 'Monitoring Objective', 'NAAQS Primary Monitor?',
#        'Networks', 'Probe Height (m)', 'QA Primary Monitor?'],
#       dtype='object')

# %% [markdown]
# Función que muestra las relaciones entre todas las variables

# %%
sns.pairplot(df)

# %% [markdown]
# Distribución del consumo de

# %%
df['Daily Max Ozone Concentration'].plot.hist(bins=25, figsize=(8,4))
# histograma en 25 intervalos
'''
Histograma: ¿Cómo se distribuyen los datos por intervalos?

'''
#figsize(ancho, alto): tamaño de la figura
# Out:
# '\nHistograma: ¿Cómo se distribuyen los datos por intervalos?\n\n'

# %%
df['Daily Max Ozone Concentration'].plot.density()
'''
Densidad: ¿Dónde están concentrados los datos?

'''
# Out:
# '\nDensidad: ¿Dónde están concentrados los datos?\n\n'

# %% [markdown]
# Matriz de correlación y headmap

# %%
numeric_df=df.select_dtypes(include=[np.number])
# Selecciona solo las columnas con valores numéricos

numeric_df.corr().round(4)
# Cálculo de la correlación
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2408/1897684073.py in <cell line: 0>()
# ----> 1 numeric_df=df.select_dtypes(include=[np.number])
#       2 # Selecciona solo las columnas con valores numéricos
#       3
#       4 numeric_df.corr().round(4)
#       5 # Cálculo de la correlación
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10,7))
sns.heatmap(numeric_df.corr(),annot=True,linewidths=2)
# Mapa de color de correlaciones

'''
Horas de operación -> 0.84
Está bastante cerca de +1, por lo que
existe una fuerte relación lineal positiva.
>>> A medida que aumentan las horas de operación,
    tiende a aumentar el consumo energético.

Carga ->

'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2408/3350027455.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(10,7))
#       2 sns.heatmap(numeric_df.corr(),annot=True,linewidths=2)
#       3 # Mapa de color de correlaciones
#       4
#       5 '''
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Conjunto de características y variables

# %%
l_column = list(df.columns) # Haciendo la lista de columnas
len_feature = len(l_column) # Longitud de la lista de vectores de columna
l_column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2408/4090163860.py in <cell line: 0>()
# ----> 1 l_column = list(df.columns) # Haciendo la lista de columnas
#       2 len_feature = len(l_column) # Longitud de la lista de vectores de columna
#       3 l_column
#
# NameError: name 'df' is not defined

# %% [markdown]
# Regresión

# %%
features = [
    'Daily Obs Count',
    'Percent Complete',
    'Site Latitude',
    'Site Longitude',
    'Elevation (m)'
]
target = 'Daily Max Ozone Concentration'

# 3. Asignar X e Y reales
X = df[features]
Y = df[target]

X.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2408/39853640.py in <cell line: 0>()
#       9
#      10 # 3. Asignar X e Y reales
# ---> 11 X = df[features]
#      12 Y = df[target]
#      13
#
# NameError: name 'df' is not defined

# %% [markdown]
# Definimos entrenamiento - prueb

# %%
from sklearn.model_selection import train_test_split
# Divide datos en enetrenamiento y prueba

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2408/721134962.py in <cell line: 0>()
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
#
# NameError: name 'X' is not defined

# %% [markdown]
# Ajuste de entrenamiento del modelo

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# machine learning
# modelo: regresión lineal
# métricas: ¿Qué tan buenas son las predicciones?

# %%
lm = LinearRegression() # Creando un objeto de Regresión Lineal 'lm'

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Verificamos la intercepsión
print("El término de intersección del modelo lineal: ", lm.intercept_)
# Out:
# El término de intersección del modelo lineal:  0.06220369151673505

# %%
# Verificamos el modelo lineal
print("Los coeficientes del modelo lineal:", lm.coef_)
# Out:
# Los coeficientes del modelo lineal: [ 1.49091159e-02 -2.34547889e-03  1.15804682e-04  5.09844248e-04
#   4.51149185e-06]

# %%
cdf = pd.DataFrame(data=lm.coef_, index=X_train.columns,columns=["Coefficients"])
cdf
# Out:
#                   Coefficients
# Daily Obs Count       0.014909
# Percent Complete     -0.002345
# Site Latitude         0.000116
# Site Longitude        0.000510
# Elevation (m)         0.000005

# %% [markdown]
# Cálculo de errores estándar y estadística t para los coeficientes

# %%
n=X_train.shape[0]  # Cantidad de datos de entrenamiento
k=X_train.shape[1]  # Cantidad de variables: 4
dfN=n-k   # grados de libertad
train_pred=lm.predict(X_train)  #Obtener predicciones

#calculamos el error: R a la 2
train_error = np.square(train_pred - Y_train)
sum_error = np.sum(train_error)
# qué tanto se equivoco el modelo

se=[0,0,0,0,0]
for i in range (k):
  r= (sum_error/dfN)
  # Cuánto varía el valor respecto a su promedio
  #                         selecciona variable: 'Temperatura' calcula la Temperatura promedio
  r = r/np.sum(np.square(X_train[list(X_train.columns)[i]]-X_train[list(X_train.columns)[i]].mean()))
  se[i]=np.sqrt(r) #Cálculo del error estándar

cdf['Standard Error']=se
cdf['t_statistic']=cdf['Coefficients']/cdf['Standard Error']
# ¿El coef. es grande en comparación con la incertidumbre que tiene?
# ¿ Está alejado de 0 respecto a su error estándar?
cdf
# Out:
#                   Coefficients  Standard Error  t_statistic
# Daily Obs Count       0.014909        0.000072   206.520949
# Percent Complete     -0.002345        0.000012  -190.789073
# Site Latitude         0.000116        0.000080     1.440038
# Site Longitude        0.000510        0.000127     4.020883
# Elevation (m)         0.000005        0.000001     4.082831

# %%
l = list(cdf.index)
target = 'Daily Max Ozone Concentration'

from matplotlib import gridspec
fig = plt.figure(figsize=(18, 12))
gs = gridspec.GridSpec(2, 3)

for i, var in enumerate(l):
    ax = plt.subplot(gs[i])
    ax.scatter(df[var], df[target], alpha=0.3)
    ax.set_title(f"{var}\nvs. Ozone Concentration", fontdict={'fontsize': 14})
    ax.set_xlabel(var)
    ax.set_ylabel("Ozone Concentration")

plt.tight_layout()
plt.show()

# %% [markdown]
# Matrices de evaluación de predicción, estimación de error y regresión

# %%
predictions =lm.predict(X_test)
print ("Tipo del objeto predicho", type(predictions))
print ("Tamaño del objeto predicho:", predictions.shape)
# Out:
# Tipo del objeto predicho <class 'numpy.ndarray'>
# Tamaño del objeto predicho: (4368,)

# %%
plt.figure(figsize=(10, 7))
plt.scatter(Y_test, predictions, alpha=0.3, color='blue', edgecolors='k')

# Línea de referencia ideal de 45°
min_val = min(Y_test.min(), predictions.min())
max_val = max(Y_test.max(), predictions.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', linewidth=2)

plt.title("Concentración de Ozono real vs. predicha", fontsize=20)
plt.xlabel("Concentración de Ozono real", fontsize=14)
plt.ylabel("Concentración de Ozono predicha", fontsize=14)
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %%
# Diagrama de dispersión (Homocedasticidad)
plt.figure(figsize=(10, 7))
plt.title("Valores residuales vs. predichos\n", fontsize=20)
plt.xlabel("Concentración de Ozono predicha", fontsize=14)
plt.ylabel("Residuos (Real - Predicho)", fontsize=14)
plt.axhline(0, color='red', linestyle='--', linewidth=1.5)  # Línea cero de referencia
plt.scatter(x=predictions, y=Y_test - predictions, alpha=0.3, color='royalblue')
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %% [markdown]
# Random Forest

# %%
rf_model = RandomForestRegressor(n_estimators=100, max_depth=6, random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=6, random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)
rf_mae = metrics.mean_absolute_error(Y_test, rf_predictions)
rf_mse = metrics.mean_squared_error(Y_test, rf_predictions)
rf_rmse = np.sqrt(rf_mse)
rf_r2 = metrics.r2_score(Y_test, rf_predictions)
eval_rf = pd.DataFrame({
    'Métrica': ['MAE', 'MSE', 'RMSE', 'R² Score'],
    'Valor': [round(rf_mae, 6), round(rf_mse, 6), round(rf_rmse, 6), round(rf_r2, 4)]
})
eval_rf
# Out:
#     Métrica     Valor
# 0       MAE  0.008248
# 1       MSE  0.000103
# 2      RMSE  0.010152
# 3  R² Score  0.039200

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Extraer la importancia de las características de tu modelo Random Forest real
importances = rf_model.feature_importances_
feature_names = X_train.columns

# Crear una tabla para visualizar los pesos numéricamente (equivalente a los coeficientes)
rf_importancias = pd.DataFrame(
    data=importances,
    index=feature_names,
    columns=["Importancia Relativa"]
).sort_values(by="Importancia Relativa", ascending=True)

display(rf_importancias)

# Graficar la importancia de las características
plt.figure(figsize=(10, 6))
plt.barh(rf_importancias.index, rf_importancias['Importancia Relativa'], color='forestgreen', edgecolor='black', alpha=0.8)
plt.title("Importancia de las características para predecir el Ozono\n(Random Forest)", fontsize=16)
plt.xlabel("Importancia Relativa (Reducción de Varianza)", fontsize=14)
plt.ylabel("Variables Predictoras", fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#                   Importancia Relativa
# Elevation (m)                 0.106269
# Site Latitude                 0.191458
# Site Longitude                0.195860
# Percent Complete              0.252554
# Daily Obs Count               0.253859

# %%
# Unir tus variables X e Y en una sola tabla
df_combinado = pd.concat([X, Y], axis=1)

# Mostrar las primeras 10 filas
df_combinado.head(10)
# Out:
#    Daily Obs Count  Percent Complete  Site Latitude  Site Longitude  \
# 0                1                 6      30.497478      -87.880258
# 1               17               100      30.497478      -87.880258
# 2               17               100      30.497478      -87.880258
# 3               17               100      30.497478      -87.880258
# 4               17               100      30.497478      -87.880258
# 5               17               100      30.497478      -87.880258
# 6               17               100      30.497478      -87.880258
# 7               17               100      30.497478      -87.880258
# 8               17               100      30.497478      -87.880258
# 9               17               100      30.497478      -87.880258
#
#    Elevation (m)  Daily Max Ozone Concentration
# 0          37.19                          0.023
# 1          37.19                          0.026
# 2          37.19                          0.038
# ...

# %%
import matplotlib.pyplot as plt

# Usamos el estilo Solarize_Light2
with plt.style.context(('Solarize_Light2')):
    # Recorremos las columnas de tu tabla combinada, excluyendo la última (que es el Ozono)
    for i, col in enumerate(df_combinado.columns[:-1]):
        plt.figure(figsize=(6,4))
        plt.grid(True)
        plt.xlabel('Variable: ' + col, fontsize=12)
        plt.ylabel('Concentración de Ozono', fontsize=12)

        # Graficamos la columna actual (col) vs el Ozono real
        plt.scatter(df_combinado[col], df_combinado['Daily Max Ozone Concentration'], c='red', s=50, alpha=0.6)

        # Fundamental poner esto dentro del bucle para que dibuje cada gráfico por separado
        plt.show()

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3, random_state=123
)

# %%
# Reentrenar el modelo con los datos actuales (para que coincidan las 5 características)
tree_model.fit(X_train, y_train)

# Predicciones con el modelo de Árbol de Decisión
tree_predictions = tree_model.predict(X_test)

# Cálculo de métricas de evaluación
tree_mae = metrics.mean_absolute_error(y_test, tree_predictions)
tree_mse = metrics.mean_squared_error(y_test, tree_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_r2 = metrics.r2_score(y_test, tree_predictions)

# Mostrar la tabla resumen con las métricas del árbol
eval_tree = pd.DataFrame({
    'Métrica': ['MAE', 'MSE', 'RMSE', 'R² Score'],
    'Valor': [round(tree_mae, 6), round(tree_mse, 6), round(tree_rmse, 6), round(tree_r2, 4)]
})
eval_tree
# Out:
#     Métrica     Valor
# 0       MAE  0.008273
# 1       MSE  0.000104
# 2      RMSE  0.010186
# 3  R² Score  0.032600

# %%
# Hacemos predicciones con el Árbol de Decisión
test_pred = tree_model.predict(X_test)

# Gráfico de dispersión: Real vs Predicho
plt.figure(figsize=(10, 7))
plt.scatter(x=y_test, y=test_pred, alpha=0.3, color='darkorange', edgecolors='k')
# Línea de referencia ideal de 45°
min_val = min(y_test.min(), test_pred.min())
max_val = max(y_test.max(), test_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', linewidth=2)

plt.title("Árbol de Decisión: Concentración de Ozono real vs. predicha", fontsize=16)
plt.xlabel("Concentración de Ozono real", fontsize=14)
plt.ylabel("Concentración de Ozono predicha", fontsize=14)
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# Imprimir el Error Cuadrático Medio
print("Mean squared error (MSE):", metrics.mean_squared_error(y_test, test_pred))
# Out:
# Mean squared error (MSE): 0.00010376248039693884

# %%
# Definir la cantidad de características reales (en tu caso son 5)
n_features = X_train.shape[1]

print("Importancia relativa de las características: ", tree_model.feature_importances_)

with plt.style.context('dark_background'):
    plt.figure(figsize=(10, 7))
    plt.grid(True, linestyle=':', alpha=0.5)

    # Usamos X_train.columns para que tome exactamente los nombres de tus 5 variables predictoras
    plt.yticks(range(n_features, 0, -1), X_train.columns, fontsize=14)

    plt.xlabel("Importancia relativa (normalizada) de los parámetros", fontsize=13)
    plt.ylabel("Características\n", fontsize=15)
    plt.title("Importancia de las características - Árbol de Decisión", fontsize=16)

    # Graficamos las barras horizontales con la importancia de tu modelo de árbol real
    plt.barh(range(n_features, 0, -1), width=tree_model.feature_importances_, height=0.5, color='cyan')
    plt.tight_layout()
    plt.show()
# Out:
# Importancia relativa de las características:  [0.45928025 0.05564019 0.23992573 0.20336208 0.04179175]

# %%
import statsmodels.api as sm

# %%
# Agregamos la constante a tus predictoras X
Xs = sm.add_constant(X)

# Usamos Y en mayúscula para que coincida exactamente con el tamaño de X
stat_model = sm.OLS(Y, Xs)
stat_result = stat_model.fit()

# Mostramos el resumen estadístico completo
print(stat_result.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     Daily Max Ozone Concentration   R-squared:                       0.029
# Model:                                       OLS   Adj. R-squared:                  0.028
# Method:                            Least Squares   F-statistic:                     86.09
# Date:                           Fri, 18 Sep 2026   Prob (F-statistic):           1.77e-89
# Time:                                   05:15:47   Log-Likelihood:                 46023.
# No. Observations:                          14557   AIC:                        -9.203e+04
# Df Residuals:                              14551   BIC:                        -9.199e+04
# Df Model:                                      5
# Covariance Type:                       nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
